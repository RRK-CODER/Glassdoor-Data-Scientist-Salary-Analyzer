# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Entry Level Data Science - December 2023 and M...
# 1               Entry Level Data Scientist 2023/2024
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                                      Salary Estimate  \
# 0                      $74K - $125K (Glassdoor est.)
# 1                       $48K - $78K (Glassdoor est.)
# 2                      $93K - $132K (Glassdoor est.)
# 3  Employer Provided Salary:$60.00 - $70.00 Per Hour
# 4           Employer Provided Salary:$75.00 Per Hour
#
#                                      Job Description Rating  \
# 0  Our business runs on Data, and having an accur...  4.1 ★
# 1  You may not realize it, but you’ve likely used...  4.1 ★
# 2  Company\nFederal Reserve Bank of Dallas\nWe ar...  4.1 ★
# 3  We are looking for a data scientist that will ...  4.1 ★
# 4  Job Duties/Responsibilities may include, but a...  4.1 ★
#
#                           Company Name           Location  \
# 0              NXP Semiconductors\n4.1         Austin, TX
# 1                          CPChem\n3.9  The Woodlands, TX
# 2  Federal Reserve Bank of Dallas\n4.1         Dallas, TX
# 3                     Ryden Global LLC             Remote
# 4               State of Virginia\n3.6             Remote
#
#                      Size  Founded  Type of ownership  \
# 0        10000+ Employees     2006   Company - Public
# 1  1001 to 5000 Employees     2000  Company - Private
# 2  1001 to 5000 Employees     1914   Company - Public
# 3                      -1       -1                 -1
# 4        10000+ Employees     1788         Government
#
#                     Industry  ... max_salary avg_salary  \
# 0  Electronics Manufacturing  ...        125       99.5
# 1     Chemical Manufacturing  ...         78       63.0
# 2          Banking & Lending  ...        132      112.5
# 3                         -1  ...         70       65.0
# 4  State & Regional Agencies  ...         75       75.0
#
#                         company_txt  job_state  age  python_yn  analysis_yn  \
# 0              NXP Semiconductors\n         TX   17          0            0
# 1                          CPChem\n         TX   23          0            0
# 2  Federal Reserve Bank of Dallas\n         TX  109          0            0
# 3                     Ryden Global      Remote   -1          0            1
# 4               State of Virginia\n     Remote  235          0            1
#
#   spark aws  Excel
# 0     0   0      0
# 1     0   0      0
# 2     0   0      0
# 3     0   0      0
# 4     0   0      0
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_state',
#        'age', 'python_yn', 'analysis_yn', 'spark', 'aws', 'Excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'
		
## Job title and seniority 
		
##  Fix state Los Angeles 

##  Job description length 

##  Competitor count

## hourly wage to annual 

#remove new line from job title

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    775
# na                 19
# analyst             5
# manager             2
# mle                 1
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        573
# senior    222
# jr          7
# Name: seniority, dtype: int64

# %%
df['job_state'] = df.job_state.apply(lambda x:x.strip() if x.strip().lower()!= 'United States' else 'CA')
df.job_state.value_counts()
# Out:
# CA                176
# VA                 79
# Remote             76
# NY                 55
# TX                 51
# MD                 40
# DC                 29
# NJ                 28
# IL                 26
# WA                 26
# MA                 21
# MN                 20
# FL                 19
# NC                 18
# OH                 15
# GA                 14
# United States      11
# MO                 10
# MI                  9
# CO                  9
# AZ                  9
# UT                  8
# CT                  5
# WI                  5
# PA                  5
# IA                  5
# IN                  4
# OR                  3
# AL                  3
# -1                  2
# LA                  2
# NV                  2
# KY                  2
# California          2
# ME                  1
# New York State      1
# SC                  1
# Alabama             1
# NE                  1
# RI                  1
# Illinois            1
# Colorado            1
# AR                  1
# DE                  1
# Manhattan           1
# Arizona             1
# OK                  1
# Name: job_state, dtype: int64

# %%
##  Job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0       794
# 1       873
# 2      1224
# 3       484
# 4       452
#        ...
# 797     880
# 798     661
# 799    2013
# 800     677
# 801     640
# Name: desc_len, Length: 802, dtype: int64

# %%
##  hourly wage to annual
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis=1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis=1)

# %%
df[df.hourly ==1][['hourly', 'min_salary', 'max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 3         1         120         140
# 4         1         150         150
# 15        1          48          84
# 17        1          80         100
# 18        1         152         152
# 33        1          62          74
# 132       1          80          90
# 142       1         150         160
# 153       1         108         130
# 163       1         100         110
# 165       1         160         160
# 170       1         146         152
# 192       1          90         110
# 230       1         110         130
# 243       1          80         100
# 263       1         160         160
# 278       1          50          76
# 352       1         144         192
# 401       1         150         160
# 436       1         180         200
# 495       1         100         110
# 531       1         130         150
# 588       1         160         180
# 592       1         130         150
# 617       1         120         130
# 666       1         120         130
# 667       1          62          62
# 668       1         150         150
# 673       1         100         130
# 684       1         110         130
# 708       1         180         180
# 709       1          96         116
# 730       1         180         180
# 731       1          96         116
# 754       1          96         116
# 778       1          96         116

# %%
df['company_txt'] = df['company_txt'].str.replace('\n',' ')

# %%
df['company_txt']
# Out:
# 0                  NXP Semiconductors
# 1                              CPChem
# 2      Federal Reserve Bank of Dallas
# 3                        Ryden Global
# 4                   State of Virginia
#                     ...
# 797                   Huntington Bank
# 798                             Block
# 799                           Cargill
# 800                     Wipro Limited
# 801                               GSK
# Name: company_txt, Length: 802, dtype: object

# %%
df.describe()
# Out:
#            Founded      hourly  employer_provided  min_salary  max_salary  \
# count   802.000000  802.000000         802.000000  802.000000  802.000000
# mean   1564.471322    0.044888           0.501247  108.733167  155.041147
# std     793.114548    0.207187           0.500310   32.074642   48.428147
# min      -1.000000    0.000000           0.000000   10.000000   11.000000
# 25%    1851.000000    0.000000           0.000000   87.000000  123.000000
# 50%    1969.000000    0.000000           1.000000  101.000000  146.000000
# 75%    2005.000000    0.000000           1.000000  128.000000  179.000000
# max    2022.000000    1.000000           1.000000  295.000000  359.000000
#
#        avg_salary         age   python_yn  analysis_yn       spark  \
# count  802.000000  802.000000  802.000000   802.000000  802.000000
# mean   129.074813   46.963840    0.132170     0.468828    0.038653
# std     40.406000   60.813236    0.338886     0.499339    0.192888
# min     10.500000   -1.000000    0.000000     0.000000    0.000000
# 25%    103.000000    7.000000    0.000000     0.000000    0.000000
# 50%    123.000000   22.000000    0.000000     0.000000    0.000000
# 75%    151.750000   65.000000    0.000000     1.000000    0.000000
# max    327.000000  398.000000    1.000000     1.000000    1.000000
#
#               aws       Excel     desc_len
# count  802.000000  802.000000   802.000000
# mean     0.083541    0.096010  1292.875312
# std      0.276871    0.294789  1228.351391
# min      0.000000    0.000000    86.000000
# 25%      0.000000    0.000000   644.000000
# 50%      0.000000    0.000000   889.000000
# 75%      0.000000    0.000000  1309.000000
# max      1.000000    1.000000  7972.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_state',
#        'age', 'python_yn', 'analysis_yn', 'spark', 'aws', 'Excel', 'job_simp',
#        'seniority', 'desc_len'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <Axes: >

# %%
df.avg_salary.hist()
# Out:
# <Axes: >

# %%
df.age.hist()
# Out:
# <Axes: >

# %%
df.desc_len.hist()
# Out:
# <Axes: >

# %%
df.boxplot(column = ['age', 'avg_salary', 'desc_len'])
# Out:
# <Axes: >

# %%
df[['age', 'avg_salary', 'desc_len']].corr
# Out:
# <bound method DataFrame.corr of      age  avg_salary  desc_len
# 0     17        99.5       794
# 1     23        63.0       873
# 2    109       112.5      1224
# 3     -1        65.0       484
# 4    235        75.0       452
# ..   ...         ...       ...
# 797  157       125.5       880
# 798   28       150.5       661
# 799  158       122.0      2013
# 800   78       136.0       677
# 801  193       159.0       640
#
# [802 rows x 3 columns]>

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','desc_len']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_state',
#        'age', 'python_yn', 'analysis_yn', 'spark', 'aws', 'Excel', 'job_simp',
#        'seniority', 'desc_len'],
#       dtype='object')

# %%
df[['Location', 'Size']]
# Out:
#               Location                    Size
# 0           Austin, TX        10000+ Employees
# 1    The Woodlands, TX  1001 to 5000 Employees
# 2           Dallas, TX  1001 to 5000 Employees
# 3               Remote                      -1
# 4               Remote        10000+ Employees
# ..                 ...                     ...
# 797       Columbus, OH        10000+ Employees
# 798        Seattle, WA  1001 to 5000 Employees
# 799        Wayzata, MN        10000+ Employees
# 800      Palo Alto, CA        10000+ Employees
# 801         Durham, NC        10000+ Employees
#
# [802 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_state',
#        'age', 'python_yn', 'analysis_yn', 'spark', 'aws', 'Excel', 'job_simp',
#        'seniority', 'desc_len'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state', 'python_yn', 'analysis_yn',
       'spark', 'aws', 'Excel', 'job_simp', 'seniority']]

# %%
df_cat
# Out:
#               Location                    Size  Type of ownership  \
# 0           Austin, TX        10000+ Employees   Company - Public
# 1    The Woodlands, TX  1001 to 5000 Employees  Company - Private
# 2           Dallas, TX  1001 to 5000 Employees   Company - Public
# 3               Remote                      -1                 -1
# 4               Remote        10000+ Employees         Government
# ..                 ...                     ...                ...
# 797       Columbus, OH        10000+ Employees   Company - Public
# 798        Seattle, WA  1001 to 5000 Employees  Company - Private
# 799        Wayzata, MN        10000+ Employees  Company - Private
# 800      Palo Alto, CA        10000+ Employees   Company - Public
# 801         Durham, NC        10000+ Employees   Company - Public
#
#                                     Industry  \
# 0                  Electronics Manufacturing
# 1                     Chemical Manufacturing
# 2                          Banking & Lending
# 3                                         -1
# 4                  State & Regional Agencies
# ..                                       ...
# 797                        Banking & Lending
# 798                    Security & Protective
# 799                          Crop Production
# 800  Information Technology Support Services
# 801                Biotech & Pharmaceuticals
#
#                                  Sector                     Revenue  \
# 0                         Manufacturing     $5 to $10 billion (USD)
# 1                         Manufacturing          $10+ billion (USD)
# 2                    Financial Services    Unknown / Non-Applicable
# 3                                    -1                          -1
# 4    Government & Public Administration   $25 to $100 million (USD)
# ..                                  ...                         ...
# 797                  Financial Services          $10+ billion (USD)
# 798             Management & Consulting  $100 to $500 million (USD)
# 799                         Agriculture    Unknown / Non-Applicable
# 800              Information Technology     $5 to $10 billion (USD)
# 801      Pharmaceutical & Biotechnology          $10+ billion (USD)
#
#                          company_txt job_state  python_yn  analysis_yn  spark  \
# 0                NXP Semiconductors         TX          0            0      0
# 1                            CPChem         TX          0            0      0
# 2    Federal Reserve Bank of Dallas         TX          0            0      0
# 3                      Ryden Global     Remote          0            1      0
# 4                 State of Virginia     Remote          0            1      0
# ..                               ...       ...        ...          ...    ...
# 797                 Huntington Bank         OH          0            1      0
# 798                           Block         WA          0            0      0
# 799                         Cargill         MN          1            1      0
# 800                   Wipro Limited         CA          0            0      0
# 801                             GSK         NC          0            0      0
#
#      aws  Excel        job_simp seniority
# 0      0      0              na        na
# 1      0      0  data scientist        na
# 2      0      0  data scientist        na
# 3      0      0  data scientist        na
# 4      0      0  data scientist        na
# ..   ...    ...             ...       ...
# 797    0      0  data scientist    senior
# 798    0      0  data scientist    senior
# 799    1      0              na    senior
# 800    0      0  data scientist    senior
# 801    0      0  data scientist    senior
#
# [802 rows x 15 columns]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 220
# graph for Size: total = 9
# graph for Type of ownership: total = 12
# graph for Industry: total = 67
# graph for Sector: total = 26
# graph for Revenue: total = 11
# graph for company_txt: total = 584
# graph for job_state: total = 47
# graph for python_yn: total = 2
# graph for analysis_yn: total = 2
# graph for spark: total = 2
# graph for aws: total = 2
# graph for Excel: total = 2
# graph for job_simp: total = 5
# graph for seniority: total = 3

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_state',
#        'age', 'python_yn', 'analysis_yn', 'spark', 'aws', 'Excel', 'job_simp',
#        'seniority', 'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df, index='job_simp', values='avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst         102.700000
# data scientist  129.587742
# manager         166.500000
# mle             157.500000
# na              109.657895

# %%
pd.pivot_table(df, index=['job_simp', 'seniority'], values='avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        na          97.500000
#                senior     123.500000
# data scientist jr          95.142857
#                na         119.127256
#                senior     157.794393
# manager        na         104.500000
#                senior     228.500000
# mle            na         157.500000
# na             na         100.461538
#                senior     129.583333

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index=['job_state'], values='avg_salary', aggfunc = 'count').sort_values('avg_salary', ascending=False)
# Out:
#                 avg_salary
# job_state
# CA                     167
# VA                      78
# Remote                  75
# NY                      54
# TX                      50
# MD                      39
# DC                      29
# NJ                      28
# WA                      26
# IL                      26
# FL                      19
# MA                      19
# NC                      17
# MN                      15
# OH                      14
# GA                      13
# United States           11
# MO                      10
# CO                       9
# AZ                       9
# MI                       9
# UT                       8
# PA                       5
# WI                       5
# CT                       5
# IA                       5
# AL                       3
# IN                       3
# OR                       3
# KY                       2
# California               2
# LA                       2
# NV                       2
# SC                       1
# AR                       1
# Arizona                  1
# Manhattan                1
# Colorado                 1
# RI                       1
# DE                       1
# ME                       1
# OK                       1
# NE                       1
# New York State           1
# Illinois                 1
# -1                       1

# %%
pd.set_option('display.max_rows', None)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_state',
#        'age', 'python_yn', 'analysis_yn', 'spark', 'aws', 'Excel', 'job_simp',
#        'seniority', 'desc_len'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'hourly', 'employer_provided', 'python_yn', 'analysis_yn', 'spark', 'aws', 'Excel', 'job_simp', 'seniority', 'desc_len', 'avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index=i, values='avg_salary').sort_values('avg_salary', ascending= False))
# Out:
# Rating
#         avg_salary
# Rating
# -1      129.702305
# 4.1 ★   105.738095
# Industry
#                                           avg_salary
# Industry
# Internet & Web Services                   174.200000
# Wholesale                                 173.375000
# Video Game Publishing                     170.700000
# Electronics Manufacturing                 167.083333
# General Merchandise & Superstores         166.166667
# Insurance Agencies & Brokerages           165.166667
# Stock Exchanges                           165.000000
# Photography                               163.000000
# Investment & Asset Management             160.142857
# Other Retail Stores                       156.363636
# Real Estate                               154.900000
# Gambling                                  154.000000
# Drug & Health Stores                      153.000000
# Enterprise Software & Network Solutions   151.178571
# Beauty & Wellness                         150.000000
# Transportation Equipment Manufacturing    148.333333
# Film Production                           145.500000
# Financial Transaction Processing          143.000000
# Biotech & Pharmaceuticals                 140.258065
# Restaurants & Cafes                       140.125000
# Home Furniture & Housewares Stores        140.000000
# Security & Protective                     139.666667
# Department, Clothing & Shoe Stores        139.428571
# Software Development                      139.309524
# Beauty & Personal Accessories Stores      135.000000
# Health Care Products Manufacturing        134.250000
# Telecommunications Services               134.250000
# Computer Hardware Development             133.256410
# Banking & Lending                         131.350000
# Legal                                     131.000000
# Business Consulting                       126.773810
# National Agencies                         126.500000
# Energy & Utilities                        125.500000
# Crop Production                           124.500000
# Pet & Pet Supplies Stores                 124.166667
# Insurance Carriers                        121.777778
# Consumer Electronics & Appliances Stores  121.250000
# Aerospace & Defense                       120.634615
# Health Care Services & Hospitals          118.987179
# Travel Agencies                           118.500000
# Research & Development                    117.566667
# Publishing                                116.000000
# Information Technology Support Services   115.785714
# Advertising & Public Relations            115.375000
# Hotels & Resorts                          113.333333
# -1                                        112.915789
# Broadcast Media                           112.500000
# Food & Beverage Stores                    111.000000
# Food & Beverage Manufacturing             110.642857
# Consumer Product Manufacturing            110.423077
# Civic & Social Services                   109.000000
# Architectural & Engineering Services      107.833333
# Construction                              107.166667
# Cable, Internet & Telephone Providers     105.750000
# Shipping & Trucking                       101.750000
# Machinery Manufacturing                   101.000000
# Colleges & Universities                    97.660714
# Sporting Goods Stores                      96.500000
# Accounting & Tax                           93.750000
# Staffing & Subcontracting                  93.333333
# Office Supply & Copy Stores                92.750000
# Vehicle Dealers                            92.250000
# Chemical Manufacturing                     90.000000
# Sports & Recreation                        85.000000
# State & Regional Agencies                  80.166667
# Municipal Agencies                         76.900000
# Grantmaking & Charitable Foundations       31.000000
# Sector
#                                              avg_salary
# Sector
# Real Estate                                  154.900000
# Personal Consumer Services                   150.000000
# Information Technology                       143.492032
# Pharmaceutical & Biotechnology               140.258065
# Restaurants & Food Service                   140.125000
# Retail & Wholesale                           138.904762
# Financial Services                           131.861111
# Legal                                        131.000000
# Media & Communication                        130.740000
# Insurance                                    127.976190
# Telecommunications                           127.125000
# Management & Consulting                      125.809524
# Energy, Mining & Utilities                   125.500000
# Manufacturing                                124.789474
# Agriculture                                  124.500000
# Aerospace & Defense                          120.634615
# Arts, Entertainment & Recreation             119.500000
# Healthcare                                   118.987179
# Hotels & Travel Accommodation                114.071429
# -1                                           112.915789
# Construction, Repair & Maintenance Services  107.500000
# Government & Public Administration           105.333333
# Transportation & Logistics                   101.750000
# Education                                     97.660714
# Human Resources & Staffing                    93.333333
# Nonprofit & NGO                               83.000000
# Revenue
#                                   avg_salary
# Revenue
# Unknown / Non-Applicable          136.765273
# $10+ billion (USD)                135.840909
# $5 to $10 billion (USD)           134.660377
# -1                                129.263158
# $1 to $5 billion (USD)            123.169014
# $100 to $500 million (USD)        120.880435
# $25 to $100 million (USD)         112.487500
# Less than $1 million (USD)        109.944444
# $5 to $25 million (USD)           108.795455
# $500 million to $1 billion (USD)  107.274194
# $1 to $5 million (USD)            106.854167
# hourly
#         avg_salary
# hourly
# 0       132.196475
# 1        62.652778
# employer_provided
#                    avg_salary
# employer_provided
# 1                  139.223881
# 0                  118.875000
# python_yn
#            avg_salary
# python_yn
# 0          130.331897
# 1          120.820755
# analysis_yn
#              avg_salary
# analysis_yn
# 0            133.431925
# 1            124.138298
# spark
#        avg_salary
# spark
# 1      130.645161
# 0      129.011673
# aws
#      avg_salary
# aws
# 1    138.462687
# 0    128.219048
# Excel
#        avg_salary
# Excel
# 0      130.240000
# 1      118.103896
# job_simp
#                 avg_salary
# job_simp
# manager         166.500000
# mle             157.500000
# data scientist  129.587742
# na              109.657895
# analyst         102.700000
# seniority
#            avg_salary
# seniority
# senior     157.195946
# na         118.594241
# jr          95.142857
# desc_len
#           avg_salary
# desc_len
# 1104      262.500000
# 859       253.500000
# 681       249.000000
# 5686      247.700000
# 916       247.000000
# 1374      236.250000
# 465       227.000000
# 840       225.000000
# 3977      224.500000
# 1841      224.500000
# 3552      224.500000
# 3863      222.500000
# 2250      220.000000
# 905       214.000000
# 778       212.750000
# 553       212.500000
# 736       209.000000
# 966       207.500000
# 1219      207.000000
# 866       205.000000
# 1131      205.000000
# 984       205.000000
# 573       204.000000
# 1571      204.000000
# 865       201.750000
# 3248      200.000000
# 3410      199.000000
# 772       198.500000
# 652       198.000000
# 1846      197.000000
# 1052      196.500000
# 3573      196.500000
# 945       196.000000
# 1918      195.500000
# 1275      194.000000
# 515       192.500000
# 526       192.500000
# 493       192.500000
# 1940      192.000000
# 1363      190.000000
# 288       190.000000
# 845       190.000000
# 1306       73.500000
# 4616       73.000000
# 320        72.500000
# 1247       70.000000
# 1054       70.000000
# 678        70.000000
# 160        68.000000
# 424        62.500000
# 601        62.500000
# 537        62.000000
# 689        60.000000
# 672        57.500000
# 1408       53.000000
# 3872       52.500000
# 786        52.500000
# 777        50.000000
# 1682       42.500000
# 607        34.000000
# 2496       33.000000
# 1091       31.500000
# 1280       31.000000
# 268        12.000000
# 121        10.500000
# avg_salary
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 for i in df_pivots.columns:
#       2     print(i)
# ----> 3     print(pd.pivot_table(df_pivots, index=i, values='avg_salary').sort_values('avg_salary', ascending= False))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:166, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     163             pass
#     164     values = list(values)
# --> 166 grouped = data.groupby(keys, observed=observed, sort=sort)
#     167 msg = (
#     168     "pivot_table dropped a column because it failed to aggregate. This behavior "
#     169     "is deprecated and will raise in a future version of pandas. Select only the "
#     170     "columns that can be aggregated."
#     171 )
#     172 with rewrite_warning(
#     173     target_message="The default value of numeric_only",
#     174     target_category=FutureWarning,
#     175     new_message=msg,
#     176 ):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:883, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     879     in_axis, name, gpr = True, gpr, obj[gpr]
#     880     if gpr.ndim != 1:
#     881         # non-unique columns; raise here to get the name in the
#     882         # exception message
# --> 883         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     884     exclusions.add(name)
#     885 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'avg_salary' not 1-dimensional

# %%
pd.pivot_table(df_pivots, index='Revenue', columns = 'python_yn', values = 'avg_salary', aggfunc= 'count')
# Out:
# python_yn                           0   1
# Revenue
# $1 to $5 billion (USD)             62   9
# $1 to $5 million (USD)             22   2
# $10+ billion (USD)                132  22
# $100 to $500 million (USD)         43   3
# $25 to $100 million (USD)          36   4
# $5 to $10 billion (USD)            44   9
# $5 to $25 million (USD)            39   5
# $500 million to $1 billion (USD)   30   1
# -1                                 16   3
# Less than $1 million (USD)          8   1
# Unknown / Non-Applicable          264  47

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
